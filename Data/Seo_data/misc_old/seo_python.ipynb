# %%
#pip install pandas 
import pandas as pd

# %%
df = pd.read_csv('Seo_data3.csv')

# %%
df_tested_seq= df[pd.to_numeric(df['Activity'], errors='coerce').notna()]

# %%
cols = [
    "Library ID",
    "Accession code",
    "Expressed_AAseq",
    "Syn_NTseq",
    "Activity",

]

df_tested_seq_cols = df_tested_seq[cols]

# %%
df_unique_seq = df_tested_seq_cols.drop_duplicates(subset=['Expressed_AAseq'])

# %%
df_unique_seq.to_csv('Seo_tested_seq.csv', index=False)

# %%
df_unique_seq.to_excel('Seo_tested_seq.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_unique_seq.to_excel('Seo_tested_seq.xlsx', index=False)
#
# File /opt/miniconda3/envs/predict_p450/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
